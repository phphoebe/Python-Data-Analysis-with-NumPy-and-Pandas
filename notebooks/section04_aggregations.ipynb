# %%
import pandas as pd

# %% [markdown]
# # Assignment 1: Groupby
#
# #### Top Stores by Transactions (Merchandising)
#
# Can you return a table containing the top 10 stores by total transactions in the data?
#
# Make sure they’re sorted from highest to lowest.
#
# Thanks!

# %%
# Read in transactions data -- parse dates specified here for help with later problem

transactions = pd.read_csv("../retail/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
# Group transactions by store_nbr number. Perform sum aggregation on transactions column

(transactions
 .groupby(["store_nbr"])[["transactions"]] 
 .sum() 
 .sort_values("transactions", ascending=False)  # sort in descending order
 .iloc[:10]  # Grab top 10 rows (will be highest values due to sort descending)
)
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %% [markdown]
# # Assignment 2: Groupby Multiple Columns
#
# #### Product (Merchandising) - Transactions by Store and Month
#
# Taking this analysis a layer deeper... Can you get me the total transactions by store and month?
#
# Sort the table from first month to last, then by highest transactions to lowest within each month.
#
# I'll likely analyze this data further in a dashboard software, but this will help me set up special seasonal displays

# %%
# helper code to extract month date part from date column

transactions["month"] = transactions["date"].dt.month

transactions.head()
# Out:
#         date  store_nbr  transactions  month
# 0 2013-01-01         25           770      1
# 1 2013-01-02          1          2111      1
# 2 2013-01-02          2          2358      1
# 3 2013-01-02          3          3487      1
# 4 2013-01-02          4          1922      1

# %%
# group by store number and month, sum trasactions

(transactions
 .groupby(["store_nbr", "month"])[["transactions"]]
 .sum()
 .sort_values(["month", "transactions"], ascending=[True, False] # ascending month, descending transactions
))
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]

# %% [markdown]
# # Assignment 3: Multi-Index DataFrames
#
# Multi-Index Help! (Head of Analytics)
#
# Can you help me access rows and columns with multiple indices? I’ve been struggling with multi-index DataFrames.
#
# Access:
# * Grab Store 3, Month 1
# * Then, select the column storing the mean of transactions
#
# Fix:
# * Drop the outer layer of the column Index
# * Reset the row index so it is the default integer index

# %%
# Ross' grouped DataFrame code, run this first

grouped = (
    transactions.groupby(["store_nbr", "month"])
    .agg({"transactions": ["sum", "mean"]})
    .sort_values(by=["month", ("transactions", "sum")], ascending=[True, False])
)

# %%
# df grouped by store and month with two aggregation columns

grouped.head()
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 44        1           628438  4246.202703
# 47        1           568824  3843.405405
# 45        1           538370  3637.635135
# 46        1           522763  3532.182432
# 3         1           463260  3151.428571

# %%
# Grab store 3, month 1 from multi-index (both values are integers)

grouped.loc[(3, 1)] # equivalent to grouped.iloc[4]
# Out:
# transactions  sum     463260.000000
#               mean      3151.428571
# Name: (3, 1), dtype: float64

# %%
# Grab mean column in column multi-index

grouped.loc[:, [("transactions", "mean")]] 

# equivalent to grouped.iloc[:, 1] (all rows, second column)
# wrap the integer in brackets return a dataframe: grouped.iloc[:, [1]]
# Out:
#                 transactions
#                         mean
# store_nbr month
# 44        1      4246.202703
# 47        1      3843.405405
# 45        1      3637.635135
# 46        1      3532.182432
# 3         1      3151.428571
# ...                      ...
# 32        12      718.058333
# 21        12     1402.133333
# 42        12     1279.016667
# 29        12     1277.116667
# 22        12      844.166667
#
# [641 rows x 1 columns]

# %%
# Drop level from column index (axis=1), then reset index
# Drop "transactions" level from column index, then reset index

grouped.droplevel(0, axis=1).reset_index()
# Out:
#      store_nbr  month     sum         mean
# 0           44      1  628438  4246.202703
# 1           47      1  568824  3843.405405
# 2           45      1  538370  3637.635135
# 3           46      1  522763  3532.182432
# 4            3      1  463260  3151.428571
# ..         ...    ...     ...          ...
# 636         32     12   86167   718.058333
# 637         21     12   84128  1402.133333
# 638         42     12   76741  1279.016667
# 639         29     12   76627  1277.116667
# 640         22     12   50650   844.166667
#
# [641 rows x 4 columns]

# %% [markdown]
# # Assignment 4: The Agg Method
#
# #### Bonus Rate and Bonus Payable (Accounting)
#
# Calculate the mean of target met by store, and the sum of bonuses to be paid to each store.
#
# Sort them by highest to lowest bonus payout.
#
# Then, do the same for day of week and month.

# %%
# Recreate table from section 3

transactions = transactions.assign(
    target_pct=transactions["transactions"] / 2500,
    met_target=(transactions["transactions"] / 2500) >= 1,
    bonus_payable=((transactions["transactions"] / 2500) >= 1) * 100,
    month=transactions.date.dt.month,
    day_of_week=transactions.date.dt.dayofweek,
)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %% [markdown]
# _By Store:_

# %%
# Group transactions by store number to get store level stats 
# use agg to calculate mean of met_target, sum of transactions by store
# sort values by bonus payable in descending order

(transactions.groupby("store_nbr")
 .agg({"met_target": "mean", "bonus_payable": "sum"})
 .sort_values(by=["bonus_payable"], ascending=False) # equivalent to .sort_values("bonus_payable", ascending=False) 
)
# Out:
#            met_target  bonus_payable
# store_nbr
# 47           0.999404         167600
# 44           0.998807         167500
# 45           0.997615         167300
# 3            0.998210         167300
# 46           0.989267         165900
# 8            0.888425         148900
# 48           0.690519         115800
# 49           0.637448         106900
# 50           0.453190          76000
# 11           0.296539          49700
# 34           0.217521          36500
# 24           0.175016          27600
# 9            0.100835          16900
# 38           0.041120           6900
# 52           0.322034           3800
# 51           0.021467           3600
# 6            0.018496           3100
# 2            0.017293           2900
# 25           0.016718           2700
# 20           0.022002           2000
# 4            0.007757           1300
# 31           0.007747           1300
# 7            0.007164           1200
# 1            0.006563           1100
# 5            0.006559           1100
# 37           0.005364            900
# 21           0.009358            700
# 39           0.003576            600
# 17           0.002389            400
# 53           0.002571            300
# 29           0.001144            100
# 14           0.000611            100
# 36           0.000645            100
# 18           0.000639            100
# 43           0.000598            100
# 42           0.000000              0
# 41           0.000000              0
# 40           0.000000              0
# 28           0.000000              0
# 35           0.000000              0
# 33           0.000000              0
# 32           0.000000              0
# 30           0.000000              0
# 27           0.000000              0
# 26           0.000000              0
# 23           0.000000              0
# 22           0.000000              0
# 19           0.000000              0
# 16           0.000000              0
# 15           0.000000              0
# 13           0.000000              0
# 12           0.000000              0
# 10           0.000000              0
# 54           0.000000              0

# %% [markdown]
# _By Month:_

# %%
# Group transactions by month to get month level stats 
# use agg to calculate mean of met_target, sum of transactions by store
# sort values by bonus payable in descending order

(transactions.groupby("month")
 .agg({"met_target": "mean", "bonus_payable": "sum"})
 .sort_values(by=["bonus_payable"], ascending=False)
)
# Out:
#        met_target  bonus_payable
# month
# 12       0.255640         154100
# 5        0.170792         131800
# 3        0.169461         130400
# 4        0.174469         129700
# 7        0.162486         126300
# 2        0.174230         121700
# 6        0.161706         121700
# 8        0.174189         120800
# 1        0.163723         119600
# 11       0.163943          98300
# 10       0.158450          97700
# 9        0.162281          96200

# %% [markdown]
# _By Weekday:_

# %%
# Group transactions by day of week to get day of week level stats 
# use agg to calculate mean of met_target, sum of transactions by store
# sort values by bonus payable in descending order

(transactions
 .groupby(["day_of_week"])
 .agg({"met_target": "mean", "bonus_payable": "sum"})
 .sort_values("bonus_payable", ascending=False)
)
# Out:
#              met_target  bonus_payable
# day_of_week
# 5              0.222204         266400
# 6              0.204001         241700
# 4              0.179007         213000
# 0              0.160214         191600
# 2              0.160572         191000
# 1              0.146299         175500
# 3              0.142077         169100

# %% [markdown]
# # Assignment 4: Transform
#
# #### Store Transactions Vs. Average (Accounting)
#
# Calculate the mean of transactions by store number and day of week while keeping row numbers.
#
# Then compare the performance of each row to its day of week average. (difference between transactions and daily avg)

# %%
# Use trasnactions table created in Assignment 3

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
# Assign method for column creation

transactions.assign(
    # use transform to create store level average transactions by day
    avg_store_transactions = (transactions
                              .groupby(["store_nbr", "day_of_week"])
                              ["transactions"]
                              .transform("mean")),
    
    # Then create a difference column subtracting the store average from that days transactions
    difference = lambda x: x["transactions"] - x["avg_store_transactions"] # x is our dataframe
)
# Out:
#             date  store_nbr  transactions  month  target_pct  met_target  \
# 0     2013-01-01         25           770      1      0.3080       False
# 1     2013-01-02          1          2111      1      0.8444       False
# 2     2013-01-02          2          2358      1      0.9432       False
# 3     2013-01-02          3          3487      1      1.3948        True
# 4     2013-01-02          4          1922      1      0.7688       False
# ...          ...        ...           ...    ...         ...         ...
# 83483 2017-08-15         50          2804      8      1.1216        True
# 83484 2017-08-15         51          1573      8      0.6292       False
# 83485 2017-08-15         52          2255      8      0.9020       False
# 83486 2017-08-15         53           932      8      0.3728       False
# 83487 2017-08-15         54           802      8      0.3208       False
#
#        bonus_payable  day_of_week  avg_store_transactions  difference
# 0                  0            1              740.245690   29.754310
# 1                  0            2             1870.782427  240.217573
# 2                  0            2             1952.652720  405.347280
# 3                100            2             3142.682008  344.317992
# 4                  0            2             1499.569038  422.430962
# ...              ...          ...                     ...         ...
# 83483            100            1             2342.410788  461.589212
# 83484              0            1             1548.448133   24.551867
# 83485              0            1             1892.588235  362.411765
# 83486              0            1              877.214286   54.785714
# 83487              0            1              817.721992  -15.721992
#
# [83488 rows x 10 columns]

# %%
# Take a peek at store level aggregate values for store 25 to validate column

(transactions
 .query("store_nbr == 25")
 .groupby(["day_of_week"])
 .agg({"transactions": "mean"})
)
# Out:
#              transactions
# day_of_week
# 0              808.830435
# 1              740.245690
# 2              849.978261
# 3              800.818182
# 4             1102.817391
# 5             1376.090517
# 6              909.604348

# %% [markdown]
# # Assignment 5: Pivot
#
# Pivot transactions with store number as index, columns day of week, with the sum of bonus payable as cells.
#
# Filter to stores that had a non-zero bonus payable and create a heatmap.
#
# Then unpivot (melt) the table so we have one row for each store and day of the week with the corresponding total owed.

# %%
# Use transactions table (ok if includes columns from assignment 4 or not)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
# Filter out all rows with 0 bonus. 

(transactions.loc[transactions["bonus_payable"] != 0]
.pivot_table(
    index="store_nbr",       # store number as rows
    columns="day_of_week",   # day of week as columns
    values="bonus_payable",  # aggregate bonus payable column
    aggfunc="sum")           # sum bonus payable
.iloc[:10]                   # optional filter to reduce table size
.style.background_gradient(cmap="RdYlGn", axis=1 ))  # apply RdYlGn colormap to pivoted DF; 
                                                     # axis=1 to apply to columns (where are the hot spots for each store)
# Out:
# <style type="text/css">
# #T_50ed8_row0_col0, #T_50ed8_row0_col3, #T_50ed8_row1_col3, #T_50ed8_row1_col4, #T_50ed8_row3_col0, #T_50ed8_row3_col3, #T_50ed8_row3_col5, #T_50ed8_row4_col0, #T_50ed8_row6_col0, #T_50ed8_row6_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_50ed8_row0_col1, #T_50ed8_row0_col2, #T_50ed8_row1_col1, #T_50ed8_row2_col0, #T_50ed8_row2_col5, #T_50ed8_row3_col1, #T_50ed8_row3_col2, #T_50ed8_row4_col1, #T_50ed8_row4_col2, #T_50ed8_row5_col5, #T_50ed8_row6_col1, #T_50ed8_row6_col2, #T_50ed8_row7_col2, #T_50ed8_row8_col5, #T_50ed8_row9_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_50ed8_row0_col4, #T_50ed8_row1_col6, #T_50ed8_row2_col6, #T_50ed8_row3_col4, #T_50ed8_row4_col3, #T_50ed8_row4_col4, #T_50ed8_row4_col5, #T_50ed8_row5_col4, #T_50ed8_row6_col4, #T_50ed8_row6_col5, #T_50ed8_row7_col3, #T_50ed8_row8_col4, #T_50ed8_row9_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_50ed8_row0_col5, #T_50ed8_row0_col6, #T_50ed8_row3_col6, #T_50ed8_row4_col6, #T_50ed8_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_50ed8_row1_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_50ed8_row1_col2, #T_50ed8_row1_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_50ed8_row2_col1, #T_50ed8_row2_col2, #T_50ed8_row2_col3, #T_50ed8_row2_col4 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_50ed8_row5_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_50ed8_row5_col1, #T_50ed8_row5_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_50ed8_row5_col3, #T_50ed8_row5_col6 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_50ed8_row7_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_50ed8_row7_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_50ed8_row7_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_50ed8_row7_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_50ed8_row7_col6 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_50ed8_row8_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_50ed8_row8_col1, #T_50ed8_row8_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_50ed8_row8_col3 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_50ed8_row8_col6 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_50ed8_row9_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_50ed8_row9_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_50ed8_row9_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_50ed8_row9_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_50ed8_row9_col5 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50ed8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >day_of_week</th>
#       <th id="T_50ed8_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_50ed8_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_50ed8_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_50ed8_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_50ed8_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_50ed8_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_50ed8_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >store_nbr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50ed8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_50ed8_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_50ed8_row0_col1" class="data row0 col1" >300.000000</td>
#       <td id="T_50ed8_row0_col2" class="data row0 col2" >300.000000</td>
#       <td id="T_50ed8_row0_col3" class="data row0 col3" >200.000000</td>
#       <td id="T_50ed8_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_50ed8_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_50ed8_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_50ed8_row1_col0" class="data row1 col0" >300.000000</td>
#       <td id="T_50ed8_row1_col1" class="data row1 col1" >600.000000</td>
#       <td id="T_50ed8_row1_col2" class="data row1 col2" >500.000000</td>
#       <td id="T_50ed8_row1_col3" class="data row1 col3" >400.000000</td>
#       <td id="T_50ed8_row1_col4" class="data row1 col4" >400.000000</td>
#       <td id="T_50ed8_row1_col5" class="data row1 col5" >500.000000</td>
#       <td id="T_50ed8_row1_col6" class="data row1 col6" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_50ed8_row2_col0" class="data row2 col0" >24000.000000</td>
#       <td id="T_50ed8_row2_col1" class="data row2 col1" >23900.000000</td>
#       <td id="T_50ed8_row2_col2" class="data row2 col2" >23900.000000</td>
#       <td id="T_50ed8_row2_col3" class="data row2 col3" >23900.000000</td>
#       <td id="T_50ed8_row2_col4" class="data row2 col4" >23900.000000</td>
#       <td id="T_50ed8_row2_col5" class="data row2 col5" >24000.000000</td>
#       <td id="T_50ed8_row2_col6" class="data row2 col6" >23700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_50ed8_row3_col0" class="data row3 col0" >200.000000</td>
#       <td id="T_50ed8_row3_col1" class="data row3 col1" >300.000000</td>
#       <td id="T_50ed8_row3_col2" class="data row3 col2" >300.000000</td>
#       <td id="T_50ed8_row3_col3" class="data row3 col3" >200.000000</td>
#       <td id="T_50ed8_row3_col4" class="data row3 col4" >100.000000</td>
#       <td id="T_50ed8_row3_col5" class="data row3 col5" >200.000000</td>
#       <td id="T_50ed8_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_50ed8_row4_col0" class="data row4 col0" >200.000000</td>
#       <td id="T_50ed8_row4_col1" class="data row4 col1" >300.000000</td>
#       <td id="T_50ed8_row4_col2" class="data row4 col2" >300.000000</td>
#       <td id="T_50ed8_row4_col3" class="data row4 col3" >100.000000</td>
#       <td id="T_50ed8_row4_col4" class="data row4 col4" >100.000000</td>
#       <td id="T_50ed8_row4_col5" class="data row4 col5" >100.000000</td>
#       <td id="T_50ed8_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_50ed8_row5_col0" class="data row5 col0" >400.000000</td>
#       <td id="T_50ed8_row5_col1" class="data row5 col1" >500.000000</td>
#       <td id="T_50ed8_row5_col2" class="data row5 col2" >500.000000</td>
#       <td id="T_50ed8_row5_col3" class="data row5 col3" >300.000000</td>
#       <td id="T_50ed8_row5_col4" class="data row5 col4" >200.000000</td>
#       <td id="T_50ed8_row5_col5" class="data row5 col5" >900.000000</td>
#       <td id="T_50ed8_row5_col6" class="data row5 col6" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_50ed8_row6_col0" class="data row6 col0" >200.000000</td>
#       <td id="T_50ed8_row6_col1" class="data row6 col1" >300.000000</td>
#       <td id="T_50ed8_row6_col2" class="data row6 col2" >300.000000</td>
#       <td id="T_50ed8_row6_col3" class="data row6 col3" >200.000000</td>
#       <td id="T_50ed8_row6_col4" class="data row6 col4" >100.000000</td>
#       <td id="T_50ed8_row6_col5" class="data row6 col5" >100.000000</td>
#       <td id="T_50ed8_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50ed8_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_50ed8_row7_col0" class="data row7 col0

# %%
(transactions.loc[transactions["bonus_payable"] != 0]
.pivot_table(
    index="store_nbr",       # store number as rows
    columns="day_of_week",   # day of week as columns
    values="bonus_payable",  # aggregate bonus payable column
    aggfunc="sum")           # sum bonus payable
.iloc[:10]                   # optional filter to reduce table size
.style.background_gradient(cmap="Blues", axis=1 ))
# Out:
# <style type="text/css">
# #T_64190_row0_col0, #T_64190_row0_col3, #T_64190_row1_col3, #T_64190_row1_col4, #T_64190_row3_col0, #T_64190_row3_col3, #T_64190_row3_col5, #T_64190_row4_col0, #T_64190_row6_col0, #T_64190_row6_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_64190_row0_col1, #T_64190_row0_col2, #T_64190_row1_col1, #T_64190_row2_col0, #T_64190_row2_col5, #T_64190_row3_col1, #T_64190_row3_col2, #T_64190_row4_col1, #T_64190_row4_col2, #T_64190_row5_col5, #T_64190_row6_col1, #T_64190_row6_col2, #T_64190_row7_col2, #T_64190_row8_col5, #T_64190_row9_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_64190_row0_col4, #T_64190_row1_col6, #T_64190_row2_col6, #T_64190_row3_col4, #T_64190_row4_col3, #T_64190_row4_col4, #T_64190_row4_col5, #T_64190_row5_col4, #T_64190_row6_col4, #T_64190_row6_col5, #T_64190_row7_col3, #T_64190_row8_col4, #T_64190_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_64190_row0_col5, #T_64190_row0_col6, #T_64190_row3_col6, #T_64190_row4_col6, #T_64190_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_64190_row1_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_64190_row1_col2, #T_64190_row1_col5 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_64190_row2_col1, #T_64190_row2_col2, #T_64190_row2_col3, #T_64190_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_64190_row5_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_64190_row5_col1, #T_64190_row5_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_64190_row5_col3, #T_64190_row5_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_64190_row7_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_64190_row7_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_64190_row7_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_64190_row7_col5 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_64190_row7_col6 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_64190_row8_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_64190_row8_col1, #T_64190_row8_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_64190_row8_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_64190_row8_col6 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_64190_row9_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_64190_row9_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_64190_row9_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_64190_row9_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_64190_row9_col5 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64190">
#   <thead>
#     <tr>
#       <th class="index_name level0" >day_of_week</th>
#       <th id="T_64190_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_64190_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_64190_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_64190_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_64190_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_64190_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_64190_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >store_nbr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64190_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_64190_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_64190_row0_col1" class="data row0 col1" >300.000000</td>
#       <td id="T_64190_row0_col2" class="data row0 col2" >300.000000</td>
#       <td id="T_64190_row0_col3" class="data row0 col3" >200.000000</td>
#       <td id="T_64190_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_64190_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_64190_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_64190_row1_col0" class="data row1 col0" >300.000000</td>
#       <td id="T_64190_row1_col1" class="data row1 col1" >600.000000</td>
#       <td id="T_64190_row1_col2" class="data row1 col2" >500.000000</td>
#       <td id="T_64190_row1_col3" class="data row1 col3" >400.000000</td>
#       <td id="T_64190_row1_col4" class="data row1 col4" >400.000000</td>
#       <td id="T_64190_row1_col5" class="data row1 col5" >500.000000</td>
#       <td id="T_64190_row1_col6" class="data row1 col6" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_64190_row2_col0" class="data row2 col0" >24000.000000</td>
#       <td id="T_64190_row2_col1" class="data row2 col1" >23900.000000</td>
#       <td id="T_64190_row2_col2" class="data row2 col2" >23900.000000</td>
#       <td id="T_64190_row2_col3" class="data row2 col3" >23900.000000</td>
#       <td id="T_64190_row2_col4" class="data row2 col4" >23900.000000</td>
#       <td id="T_64190_row2_col5" class="data row2 col5" >24000.000000</td>
#       <td id="T_64190_row2_col6" class="data row2 col6" >23700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_64190_row3_col0" class="data row3 col0" >200.000000</td>
#       <td id="T_64190_row3_col1" class="data row3 col1" >300.000000</td>
#       <td id="T_64190_row3_col2" class="data row3 col2" >300.000000</td>
#       <td id="T_64190_row3_col3" class="data row3 col3" >200.000000</td>
#       <td id="T_64190_row3_col4" class="data row3 col4" >100.000000</td>
#       <td id="T_64190_row3_col5" class="data row3 col5" >200.000000</td>
#       <td id="T_64190_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_64190_row4_col0" class="data row4 col0" >200.000000</td>
#       <td id="T_64190_row4_col1" class="data row4 col1" >300.000000</td>
#       <td id="T_64190_row4_col2" class="data row4 col2" >300.000000</td>
#       <td id="T_64190_row4_col3" class="data row4 col3" >100.000000</td>
#       <td id="T_64190_row4_col4" class="data row4 col4" >100.000000</td>
#       <td id="T_64190_row4_col5" class="data row4 col5" >100.000000</td>
#       <td id="T_64190_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_64190_row5_col0" class="data row5 col0" >400.000000</td>
#       <td id="T_64190_row5_col1" class="data row5 col1" >500.000000</td>
#       <td id="T_64190_row5_col2" class="data row5 col2" >500.000000</td>
#       <td id="T_64190_row5_col3" class="data row5 col3" >300.000000</td>
#       <td id="T_64190_row5_col4" class="data row5 col4" >200.000000</td>
#       <td id="T_64190_row5_col5" class="data row5 col5" >900.000000</td>
#       <td id="T_64190_row5_col6" class="data row5 col6" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_64190_row6_col0" class="data row6 col0" >200.000000</td>
#       <td id="T_64190_row6_col1" class="data row6 col1" >300.000000</td>
#       <td id="T_64190_row6_col2" class="data row6 col2" >300.000000</td>
#       <td id="T_64190_row6_col3" class="data row6 col3" >200.000000</td>
#       <td id="T_64190_row6_col4" class="data row6 col4" >100.000000</td>
#       <td id="T_64190_row6_col5" class="data row6 col5" >100.000000</td>
#       <td id="T_64190_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64190_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_64190_row7_col0" class="data row7 col0

# %%
# Build pivot table from above then melt

(transactions
 .loc[transactions["bonus_payable"] != 0]
 .pivot_table(index="store_nbr",
              columns="day_of_week",
              values="bonus_payable",
              aggfunc="sum")
 .reset_index()  # get necessary columns out of index before melting
 .melt(id_vars="store_nbr", value_name="bonus_payable"))  # specify store_nbr to melt around and name bonus column
# Out:
#      store_nbr day_of_week  bonus_payable
# 0            1           0          200.0
# 1            2           0          300.0
# 2            3           0        24000.0
# 3            4           0          200.0
# 4            5           0          200.0
# ..         ...         ...            ...
# 240         49           6        21600.0
# 241         50           6        23200.0
# 242         51           6          200.0
# 243         52           6         1500.0
# 244         53           6            NaN
#
# [245 rows x 3 columns]
